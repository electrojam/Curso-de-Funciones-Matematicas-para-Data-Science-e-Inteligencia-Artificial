# %% [markdown]
# <a href="https://colab.research.google.com/github/electrojam/Curso-de-Funciones-Matematicas-para-Data-Science-e-Inteligencia-Artificial/blob/main/Funciones_algebraicas_lineales.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ##Función Lineal
#
# f(x)=mx+b

# %%
N = 100
m = -1
b = 3

def f(x):
  return m*x+b

x = np.linspace(-10,10, num=N)

y = f(x)

fig, ax = plt.subplots()
ax.plot(x,y)
ax.grid()
